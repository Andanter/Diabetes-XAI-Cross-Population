# %%
import pandas as pd

harmonization =pd.DataFrame([
    ["Diabetes outcome", "DIABETE3", "b5/b6", "KHdiabB12", "1 =diabetes, 0 = no diabetes"],
    ["Age", "_AGE80", "age", "age10B", "numeric or grouped age"],
    ["Sex", "SEX", "sex", "sex", "1=male, 0=female"],
    ["BMI", "_BMI5", "derived fro m11 and m12","PAbmiB_k2", "continuous in BRFSS/Uganda; grouped in GEDA"],
    ["Hypertension", "BPHIGH4", "derived from m4-m7", "KHhyp12", "1=yes, 0=no"],
    ["Current smoking", "_RFSMOK3", "t1", "RCstatE_k3", "1=yes, 0=no"],
    ["Physical activity", "_TOTINDA", "derived from p-variables", "KAehispaq6", "1=active, 0=inactive"]
], columns=["Concept", "BRFSS", "Uganda", "GEDA","Final coding"])

harmonization
# Out:
#              Concept     BRFSS                    Uganda        GEDA  \
# 0   Diabetes outcome  DIABETE3                     b5/b6   KHdiabB12
# 1                Age    _AGE80                       age      age10B
# 2                Sex       SEX                       sex         sex
# 3                BMI     _BMI5   derived fro m11 and m12   PAbmiB_k2
# 4       Hypertension   BPHIGH4        derived from m4-m7     KHhyp12
# 5    Current smoking  _RFSMOK3                        t1  RCstatE_k3
# 6  Physical activity  _TOTINDA  derived from p-variables  KAehispaq6
#
#                                   Final coding
# 0                 1 =diabetes, 0 = no diabetes
# 1                       numeric or grouped age
# 2                             1=male, 0=female
# 3  continuous in BRFSS/Uganda; grouped in GEDA
# 4                                  1=yes, 0=no
# 5                                  1=yes, 0=no
# 6                         1=active, 0=inactive

# %%
harmonization.to_csv("/content/harmonization_table.csv", index=False)
harmonization.to_excel("/content/harmonization_table.xlsx", index=False)

print("Saved harmonization table.")
# Out:
# Saved harmonization table.
